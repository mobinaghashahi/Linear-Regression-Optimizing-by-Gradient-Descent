# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def generateData():

    
    num_points = 100
    start = -5
    end = 5
    X = np.linspace(start, end, num_points)
    
    Y=10*X+4
    
    mean = 0  
    std_dev = 1  
    noise = np.random.normal(mean, std_dev, num_points)
    Y=Y+noise
    return X,Y

# %%
def costFunction(x,y,w):
    return np.sum((np.dot(x,w.T) - y)**2) / len(x)

# %%
def drawLine(x,w):
    return x*w[0][1]+w[0][0]

# %%
def gradietnDesent(x,y,w,iteration,step):
   
    for i in range(iteration):
        print(f"Iter:{i}")
        print(f"w0={w[0][0]} w1={w[0][1]} cost={costFunction(x,y,w)}")
        w[0][0]-=((2*step/len(y))*(np.sum((np.dot(x,w.T)-y))))
        w[0][1]-=((2*step/len(y))*(np.sum((np.dot(x,w.T)-y)*x)))
    return w

# %%
#generate Data
x,y=generateData()

#add bias to the data
ones_column = np.ones((x.shape[0], 1))  
x = x.reshape(-1, 1)  # تغییر شکل به (100, 1)
y = y.reshape(-1, 1)
X_with_bias = np.hstack((ones_column,x)) 


#initial w
w=np.array([[203, 400]])


w=gradietnDesent(X_with_bias,y,w,100,0.06)
# Out:
# Iter:0
# w0=203 w1=400 cost=1333046.1243656198
# Iter:1
# w0=179 w1=-18 cost=37291.67832677471
# Iter:2
# w0=157 w1=-7 cost=25873.286147968247
# Iter:3
# w0=138 w1=-5 cost=19875.30614704048
# Iter:4
# w0=121 w1=-3 cost=15131.599943024039
# Iter:5
# w0=106 w1=-2 cost=11632.905822602801
# Iter:6
# w0=93 w1=0 cost=8775.7404784023
# Iter:7
# w0=82 w1=0 cost=6937.30866946403
# Iter:8
# w0=72 w1=1 cost=5315.275472297562
# Iter:9
# w0=63 w1=3 cost=3900.650987912999
# Iter:10
# w0=55 w1=3 cost=3019.6096723215287
# Iter:11
# w0=48 w1=4 cost=2243.9770695119637
# Iter:12
# w0=42 w1=5 cost=1658.477998154699
# Iter:13
# w0=37 w1=6 cost=1227.112458249735
# Iter:14
# w0=33 w1=6 cost=978.591800454
# Iter:15
# w0=29 w1=7 cost=703.3597920013372
# Iter:16
# w0=25 w1=7 cost=518.8391342056018
# Iter:17
# w0=22 w1=7 cost=401.44864085880045
# Iter:18
# w0=19 w1=8 cost=260.35016385843824
# Iter:19
# w0=17 w1=8 cost=204.0898349605707
# Iter:20
# w0=15 w1=8 cost=155.82950606270313
# Iter:21
# w0=13 w1=8 cost=115.56917716483551
# Iter:22
# w0=11 w1=9 cost=58.60423161677406
# Iter:23
# w0=10 w1=9 cost=45.47406716784028
# Iter:24
# w0=9 w1=9 cost=34.3439027189065
# Iter:25
# w0=8 w1=9 cost=25.21373826997272
# Iter:26
# w0=7 w1=9 cost=18.08357382103894
# Iter:27
# w0=6 w1=9 cost=12.953409372105154
# Iter:28
# w0=5 w1=9 cost=9.823244923171373
# Iter:29
# w0=4 w1=9 cost=8.693080474237592
# Iter:30
# w0=3 w1=10 cost=1.8616663784769012
# Iter:31
# w0=3 w1=10 cost=1.8616663784769012
# Iter:32
# w0=3 w1=10 cost=1.8616663784769012
# Iter:33
# w0=3 w1=10 cost=1.8616663784769012
# Iter:34
# w0=3 w1=10 cost=1.8616663784769012
# Iter:35
# w0=3 w1=10 cost=1.8616663784769012
# Iter:36
# w0=3 w1=10 cost=1.8616663784769012
# Iter:37
# w0=3 w1=10 cost=1.8616663784769012
# Iter:38
# w0=3 w1=10 cost=1.8616663784769012
# Iter:39
# w0=3 w1=10 cost=1.8616663784769012
# Iter:40
# w0=3 w1=10 cost=1.8616663784769012
# Iter:41
# w0=3 w1=10 cost=1.8616663784769012
# Iter:42
# w0=3 w1=10 cost=1.8616663784769012
# Iter:43
# w0=3 w1=10 cost=1.8616663784769012
# Iter:44
# w0=3 w1=10 cost=1.8616663784769012
# Iter:45
# w0=3 w1=10 cost=1.8616663784769012
# Iter:46
# w0=3 w1=10 cost=1.8616663784769012
# Iter:47
# w0=3 w1=10 cost=1.8616663784769012
# Iter:48
# w0=3 w1=10 cost=1.8616663784769012
# Iter:49
# w0=3 w1=10 cost=1.8616663784769012
# Iter:50
# w0=3 w1=10 cost=1.8616663784769012
# Iter:51
# w0=3 w1=10 cost=1.8616663784769012
# Iter:52
# w0=3 w1=10 cost=1.8616663784769012
# Iter:53
# w0=3 w1=10 cost=1.8616663784769012
# Iter:54
# w0=3 w1=10 cost=1.8616663784769012
# Iter:55
# w0=3 w1=10 cost=1.8616663784769012
# Iter:56
# w0=3 w1=10 cost=1.8616663784769012
# Iter:57
# w0=3 w1=10 cost=1.8616663784769012
# Iter:58
# w0=3 w1=10 cost=1.8616663784769012
# Iter:59
# w0=3 w1=10 cost=1.8616663784769012
# Iter:60
# w0=3 w1=10 cost=1.8616663784769012
# Iter:61
# w0=3 w1=10 cost=1.8616663784769012
# Iter:62
# w0=3 w1=10 cost=1.8616663784769012
# Iter:63
# w0=3 w1=10 cost=1.8616663784769012
# Iter:64
# w0=3 w1=10 cost=1.8616663784769012
# Iter:65
# w0=3 w1=10 cost=1.8616663784769012
# Iter:66
# w0=3 w1=10 cost=1.8616663784769012
# Iter:67
# w0=3 w1=10 cost=1.8616663784769012
# Iter:68
# w0=3 w1=10 cost=1.8616663784769012
# Iter:69
# w0=3 w1=10 cost=1.8616663784769012
# Iter:70
# w0=3 w1=10 cost=1.8616663784769012
# Iter:71
# w0=3 w1=10 cost=1.8616663784769012
# Iter:72
# w0=3 w1=10 cost=1.8616663784769012
# Iter:73
# w0=3 w1=10 cost=1.8616663784769012
# Iter:74
# w0=3 w1=10 cost=1.8616663784769012
# Iter:75
# w0=3 w1=10 cost=1.8616663784769012
# Iter:76
# w0=3 w1=10 cost=1.8616663784769012
# Iter:77
# w0=3 w1=10 cost=1.8616663784769012
# Iter:78
# w0=3 w1=10 cost=1.8616663784769012
# Iter:79
# w0=3 w1=10 cost=1.8616663784769012
# Iter:80
# w0=3 w1=10 cost=1.8616663784769012
# Iter:81
# w0=3 w1=10 cost=1.8616663784769012
# Iter:82
# w0=3 w1=10 cost=1.8616663784769012
# Iter:83
# w0=3 w1=10 cost=1.8616663784769012
# Iter:84
# w0=3 w1=10 cost=1.8616663784769012
# Iter:85
# w0=3 w1=10 cost=1.8616663784769012
# Iter:86
# w0=3 w1=10 cost=1.8616663784769012
# Iter:87
# w0=3 w1=10 cost=1.8616663784769012
# Iter:88
# w0=3 w1=10 cost=1.8616663784769012
# Iter:89
# w0=3 w1=10 cost=1.8616663784769012
# Iter:90
# w0=3 w1=10 cost=1.8616663784769012
# Iter:91
# w0=3 w1=10 cost=1.8616663784769012
# Iter:92
# w0=3 w1=10 cost=1.8616663784769012
# Iter:93
# w0=3 w1=10 cost=1.8616663784769012
# Iter:94
# w0=3 w1=10 cost=1.8616663784769012
# Iter:95
# w0=3 w1=10 cost=1.8616663784769012
# Iter:96
# w0=3 w1=10 cost=1.8616663784769012
# Iter:97
# w0=3 w1=10 cost=1.8616663784769012
# Iter:98
# w0=3 w1=10 cost=1.8616663784769012
# Iter:99
# w0=3 w1=10 cost=1.8616663784769012

# %%
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, drawLine(x, w), color='red', label='Prediction (Closed Form)')
plt.title(f"Polynomial Regression (Degree {1})")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.legend()
plt.show()
